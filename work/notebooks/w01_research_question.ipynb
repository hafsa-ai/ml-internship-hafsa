# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hafsa-ai/ml-internship-hafsa/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from datasets import load_dataset
import pandas as pd

# Use your token here.
# Note: In a production environment, use environment variables or a secret manager.
token = "YOUR_HF_TOKEN_HERE"

# Load the dataset
ds = load_dataset(
    "FlyRank/internship-warehouse",
    "fact_content_daily_performance",
    split="train",
    token=token
)

# Convert to DataFrame once
df = ds.to_pandas()

# Verify the load
print(f"Data loaded successfully. Shape: {df.shape}")
print("Available columns:", df.columns.tolist())
print("\nFirst 3 rows:")
print(df.head(3))

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Quick look at the data
# Ensure 'ds' and 'df' are defined from the previous loading cell

# 1. Show the distribution of our calculated status to verify the logic
print("Content Status Distribution:")
print(df['status'].value_counts())

# 2. Show the top 3 pages by Opportunity Score
# These are the pages a mentor should act on first
top_opportunities = df.sort_values(by='opportunity_score', ascending=False)[['page', 'opportunity_score', 'status']]
print("\nTop 3 Pages for Mentor Review:")
print(top_opportunities.head(3))

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# 1. Load the dataset
# Replace 'your_file.csv' with the path to your actual starter file
df = pd.read_csv('your_file.csv')

# 2. Basic Inspection
print("Dataset Shape:", df.shape)
print(df.head())

# 3. Extract 2-3 real numbers to justify your project
# Example 1: Total volume of records
total_records = len(df)
print(f"Total number of records: {total_records}")

# Example 2: Average value of a key metric (e.g., 'Amount' or 'Sales')
# Ensure you replace 'Amount' with a relevant column name from your dataset
avg_value = df['Amount'].mean()
print(f"Average value per record: {avg_value:.2f}")

# Example 3: Maximum value observed
max_value = df['Amount'].max()
print(f"Maximum value observed: {max_value}")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# CODE: Demonstrating data limitations
# We inspect the correlation matrix to show that metrics are related,
# but we do not assume they cause one another.

# 1. Calculate correlation matrix
correlation_matrix = df[['clicks', 'impressions', 'ctr']].corr()

print("Correlation Matrix (Observed relationships, not causal proof):")
print(correlation_matrix)

# 2. Check for missing values which define the limits of our claim
missing_values = df.isnull().sum()
print("\nData gaps/Missing values (Where our model cannot make claims):")
print(missing_values[missing_values > 0])

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
